# %% [markdown]
# <a href="https://colab.research.google.com/github/Udhay2898/Data-Cleaning/blob/Master/Data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Loading Dataset
df = pd.read_csv('/content/drive/MyDrive/Data Sets/Cricket Stat.csv')

df.sample(3)
# Out:
#               Player  Match  Innings  Not Outs  Runs  Balls Faced  100s  50s  \
# 29          AC Voges      9        7         3   181          143     0    0
# 209  JJ van der Wath      3        3         1    18           16     0    0
# 484    ST Jayasuriya     30       30         2   768          532     1    4
#
#      Ducks  4s  ...  Maiden  Runs Given  Wkts  4 W   5 W  Catches  Stumping  \
# 29       0  15  ...       0          76     0     0    0        1         0
# 209      1   1  ...       0         129     3     0    0        0         0
# 484      2  84  ...       1         390    13     0    0        4         0
#
#      Bol Average  Bol SR   Econ
# 29           0.0    0.00   8.44
# 209         43.0   24.00  10.75
# 484         30.0   22.62   7.96
#
# [3 rows x 26 columns]

# %%
# Backup

df1 = df.copy()

df2 = df

# %%
# Data Cleaning

# Find Duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# Find Duplicates

df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Player, Match, Innings, Not Outs, Runs, Balls Faced, 100s, 50s, Ducks, 4s, 6s, Average, SR, High Score, Innings by Bowling, Balls Bowled, Maiden, Runs Given, Wkts, 4 W , 5 W, Catches, Stumping, Bol Average, Bol SR, Econ]
# Index: []
#
# [0 rows x 26 columns]

# %%
# Keep None Duplicate

df[df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Player, Match, Innings, Not Outs, Runs, Balls Faced, 100s, 50s, Ducks, 4s, 6s, Average, SR, High Score, Innings by Bowling, Balls Bowled, Maiden, Runs Given, Wkts, 4 W , 5 W, Catches, Stumping, Bol Average, Bol SR, Econ]
# Index: []
#
# [0 rows x 26 columns]

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 555    False
# 556    False
# 557    False
# 558    False
# 559    False
# Length: 560, dtype: bool

# %%
# Outliers
df1 = pd.read_csv('/content/drive/MyDrive/Data Sets/shopping.csv')

df1.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.749949
# std    1125.977353    15.207589              23.685392       0.716223
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.700000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
min_threshold, max_threshold = df1['Purchase Amount (USD)'].quantile([0.001,0.999]).round(2)

min_threshold, max_threshold
# Out:
# (20.0, 100.0)

# %%
df1.shape
# Out:
# (3900, 18)

# %%
df1[df1['Purchase Amount (USD)'] < min_threshold]
# Out:
# Empty DataFrame
# Columns: [Customer ID, Age, Gender, Item Purchased, Category, Purchase Amount (USD), Location, Size, Color, Season, Review Rating, Subscription Status, Shipping Type, Discount Applied, Promo Code Used, Previous Purchases, Payment Method, Frequency of Purchases]
# Index: []

# %%
df1[df1['Purchase Amount (USD)'] > max_threshold]
# Out:
# Empty DataFrame
# Columns: [Customer ID, Age, Gender, Item Purchased, Category, Purchase Amount (USD), Location, Size, Color, Season, Review Rating, Subscription Status, Shipping Type, Discount Applied, Promo Code Used, Previous Purchases, Payment Method, Frequency of Purchases]
# Index: []

# %%
df1 = df1[(df1['Purchase Amount (USD)'] < max_threshold) & (df1['Purchase Amount (USD)'] > min_threshold)]

df1
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...
